# %%
import numpy as np
import time

#Минор
def submatrix(M, c):
    B = [[1] * len(M) for i in range(len(M))]

    for l in range(len(M)):
        for k in range(len(M)):
            B[l][k] = M[l][k]

    B.pop(0)

    for i in range(len(B)):
        B[i].pop(c)
    return B

#Определитель методом Лапласа
def det_L(M):
    X = 0
    if len(M) != len(M[0]):
        print('Матрица не квадратная')
    else:
        if len(M) <= 2:
            return M[0][0] * M[1][1] - M[0][1] * M[1][0]
        else:
            for i in range(len(M)):
                X += ((-1)**i) * M[0][i] * det_L(submatrix(M, i))
    return X

# %%
a = np.random.rand(9, 9)
print (a)
# Out:
# [[0.55824599 0.2797091  0.05493254 0.00260945 0.61897395 0.12605443
#   0.48225978 0.37919031 0.4980278 ]
#  [0.56487728 0.85915954 0.42743157 0.11460317 0.07329855 0.06364157
#   0.73535199 0.49478873 0.35824641]
#  [0.45623938 0.63619781 0.08516377 0.8779175  0.7018486  0.59350666
#   0.25375156 0.62843375 0.67268038]
#  [0.59295827 0.19191076 0.02459934 0.2033424  0.19116656 0.49329823
#   0.11873726 0.84495793 0.28913221]
#  [0.62001355 0.35321021 0.51532263 0.59390492 0.82552698 0.60046754
#   0.82462384 0.93972272 0.99710927]
#  [0.48176772 0.34211588 0.03277894 0.85080527 0.9762223  0.51195997
#   0.74140382 0.74381626 0.22892596]
#  [0.17953824 0.7081545  0.63868199 0.5471447  0.37140749 0.22016569
#   0.87575951 0.59193731 0.9749021 ]
#  [0.66200961 0.10056736 0.75658731 0.51694301 0.03280517 0.71695557
#   0.63081469 0.18071081 0.5763016 ]
#  [0.79529755 0.22702969 0.03268252 0.90761906 0.88253783 0.51814279
#   0.30598021 0.45506833 0.3786117 ]]

# %%
start_time = time.time()
print (np.linalg.det(a))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# -0.007977796648067602
# --- 0.002039194107055664 seconds ---

# %%
start_time2 = time.time()
print (det_L(a))
print("--- %s seconds ---" % (time.time() - start_time2))
# Out:
# -0.007977796648067614
# --- 8.388994932174683 seconds ---
